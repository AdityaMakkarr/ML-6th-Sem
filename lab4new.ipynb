# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder, KBinsDiscretizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


file_path = "adult.csv"
df = pd.read_csv(file_path)

print(df.columns)
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.replace("?", np.nan, inplace=True)
print(df.isnull().sum())
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %%
categorical_cols = df.select_dtypes(include='object').columns
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
df.head()
# Out:
#    age  workclass  fnlwgt  education  education.num  marital.status  \
# 0   90          8   77053         11              9               6
# 1   82          3  132870         11              9               6
# 2   66          8  186061         15             10               6
# 3   54          3  140359          5              4               0
# 4   41          3  264663         15             10               5
#
#    occupation  relationship  race  sex  capital.gain  capital.loss  \
# 0          14             1     4    0             0          4356
# 1           3             1     4    0             0          4356
# 2          14             4     2    0             0          4356
# 3           6             4     4    0             0          3900
# 4           9             3     4    0             0          3900
#
#    hours.per.week  native.country  income
# 0              40              38       0
# 1              18              38       0
# ...

# %%
discretization_columns = ['age', 'hours.per.week']

discretizer = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='uniform') 
df[discretization_columns] = discretizer.fit_transform(df[discretization_columns])

for col in discretization_columns:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df, x=col, palette='viridis')
    plt.title(f'Frequency Distribution of Discretized {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()
df.head()
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_9740\4031812307.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='viridis')
# C:\Users\adity\AppData\Local\Temp\ipykernel_9740\4031812307.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='viridis')
#    age  workclass  fnlwgt  education  education.num  marital.status  \
# 0  4.0          8   77053         11              9               6
# 1  4.0          3  132870         11              9               6
# 2  4.0          8  186061         15             10               6
# 3  4.0          3  140359          5              4               0
# ...
